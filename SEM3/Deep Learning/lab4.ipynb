# %% [markdown]
# <a href="https://colab.research.google.com/github/Shiladitya56/Machine-Learning/blob/main/SEM3/Deep%20Learning/lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Shiladitya 2348556 ⚓

# %% [markdown]
# **Importing Necessary Libraries**
#
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from termcolor import colored
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
import tensorflow as tf
from sklearn.metrics import accuracy_score, f1_score, roc_curve, roc_auc_score, confusion_matrix, classification_report,auc

# %%
data = pd.read_csv("/content/WA_Fn-UseC_-Telco-Customer-Churn.csv")
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
# Dropping the unnecesary ID column
data = data.drop(columns=['customerID'])

# %% [markdown]
# **Exploratory Data Analysis**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7043 non-null   object
#  19  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
data.describe(include='all')
# Out:
#        gender  SeniorCitizen Partner Dependents       tenure PhoneService  \
# count    7043    7043.000000    7043       7043  7043.000000         7043
# unique      2            NaN       2          2          NaN            2
# top      Male            NaN      No         No          NaN          Yes
# freq     3555            NaN    3641       4933          NaN         6361
# mean      NaN       0.162147     NaN        NaN    32.371149          NaN
# std       NaN       0.368612     NaN        NaN    24.559481          NaN
# min       NaN       0.000000     NaN        NaN     0.000000          NaN
# 25%       NaN       0.000000     NaN        NaN     9.000000          NaN
# 50%       NaN       0.000000     NaN        NaN    29.000000          NaN
# 75%       NaN       0.000000     NaN        NaN    55.000000          NaN
# max       NaN       1.000000     NaN        NaN    72.000000          NaN
#
#        MultipleLines InternetService OnlineSecurity OnlineBackup  \
# count           7043            7043           7043         7043
# unique             3               3              3            3
# top               No     Fiber optic             No           No
# freq            3390            3096           3498         3088
# mean             NaN             NaN            NaN          NaN
# std              NaN             NaN            NaN          NaN
# min              NaN             NaN            NaN          NaN
# 25%              NaN             NaN            NaN          NaN
# 50%              NaN             NaN            NaN          NaN
# 75%              NaN             NaN            NaN          NaN
# max              NaN             NaN            NaN          NaN
#
#        DeviceProtection TechSupport StreamingTV StreamingMovies  \
# count              7043        7043        7043            7043
# unique                3           3           3               3
# top                  No          No          No              No
# freq               3095        3473        2810            2785
# mean                NaN         NaN         NaN             NaN
# std                 NaN         NaN         NaN             NaN
# min                 NaN         NaN         NaN             NaN
# 25%                 NaN         NaN         NaN             NaN
# 50%                 NaN         NaN         NaN             NaN
# 75%                 NaN         NaN         NaN             NaN
# max                 NaN         NaN         NaN             NaN
#
#               Contract PaperlessBilling     PaymentMethod  MonthlyCharges  \
# count             7043             7043              7043     7043.000000
# unique               3                2                 4             NaN
# top     Month-to-month              Yes  Electronic check             NaN
# freq              3875             4171              2365             NaN
# mean               NaN              NaN               NaN       64.761692
# std                NaN              NaN               NaN       30.090047
# min                NaN              NaN               NaN       18.250000
# 25%                NaN              NaN               NaN       35.500000
# 50%                NaN              NaN               NaN       70.350000
# 75%                NaN              NaN               NaN       89.850000
# max                NaN              NaN               NaN      118.750000
#
#        TotalCharges Churn
# count          7043  7043
# unique         6531     2
# top                    No
# freq             11  5174
# mean            NaN   NaN
# std             NaN   NaN
# min             NaN   NaN
# 25%             NaN   NaN
# 50%             NaN   NaN
# 75%             NaN   NaN
# max             NaN   NaN

# %%
data.shape
# Out:
# (7043, 20)

# %%
for col in data.select_dtypes(include='object').columns:
  print(f'{col} feature has {data[col].nunique()} unique values.')
# Out:
# gender feature has 2 unique values.
# Partner feature has 2 unique values.
# Dependents feature has 2 unique values.
# PhoneService feature has 2 unique values.
# MultipleLines feature has 3 unique values.
# InternetService feature has 3 unique values.
# OnlineSecurity feature has 3 unique values.
# OnlineBackup feature has 3 unique values.
# DeviceProtection feature has 3 unique values.
# TechSupport feature has 3 unique values.
# StreamingTV feature has 3 unique values.
# StreamingMovies feature has 3 unique values.
# Contract feature has 3 unique values.
# PaperlessBilling feature has 2 unique values.
# PaymentMethod feature has 4 unique values.
# TotalCharges feature has 6531 unique values.
# Churn feature has 2 unique values.

# %%
sns.countplot(x='Churn',data=data,hue='Churn')
plt.title("Customer Churn Distribution")
plt.show()

# %% [markdown]
# There are no null values

# %%
data.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
fig = px.histogram(data, x="Churn", color="Contract", barmode="group", title="<b>Customer contract distribution<b>")
fig.update_layout(width=700, height=500, bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d25ddee6-1e57-4304-9e6d-8e223ef83ab1" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d25ddee6-1e57-4304-9e6d-8e223ef83ab1")) {                    Plotly.newPlot(                        "d25ddee6-1e57-4304-9e6d-8e223ef83ab1",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Contract=Month-to-month\u003cbr\u003eChurn=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Month-to-month","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Month-to-month","offsetgroup":"Month-to-month","orientation":"v","showlegend":true,"x":["No","Yes","Yes","Yes","No","No","Yes","No","Yes","No","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","Yes","No","Yes","Yes","No","No","No","Yes","No","Yes","No","Yes","Yes","No","No","Yes","No","No","No","No","No","No","Yes","No","Yes","No","No","No","No","No","No","Yes","Yes","Yes","No","No","No","Yes","No","Yes","No","Yes","No","No","Yes","No","No","Yes","No","No","Yes","Yes","Yes","No","Yes","Yes","Yes","No","No","Yes","No","No","No","No","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","No","Yes","No","Yes","Yes","Yes","No","No","No","Yes","No","No","No","No","No","No","Yes","Yes","Yes","No","No","No","No","Yes","Yes","Yes","No","No","Yes","No","Yes","No","Yes","No","No","No","Yes","Yes","Yes","Yes","No","Yes","No","Yes","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","No","No","No","No","No","No","No","Yes","No","Yes","Yes","Yes","Yes","No","No","No","No","No","Yes","Yes","No","No","Yes","No","No","No","No","Yes","Yes","No","No","No","No","Yes","No","No","Yes","Yes","No","Yes","No","No","No","Yes","No","No","Yes","Yes","Yes","No","Yes","No","No","Yes","No","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","No","No","No","No","No","No","No","No","Yes","No","Yes","No","Yes","Yes","Yes","No","No","No","No","Yes","Yes","No","No","No","No","No","No","Yes","No","Yes","No","No","No","No","No","No","No","Yes","Yes","No","No","No","Yes","No","No","No","No","No","Yes","Yes","Yes","Yes","No","No","Yes","Yes","No","No","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","No","No","Yes","Yes","No","Yes","No","Yes","Yes","No","No","Yes","No","No","Yes","No","Yes","No","No","No","Yes","Yes","No","Yes","No","No","No","No","Yes","Yes","Yes","No","Yes","No","No","No","No","No","No","Yes","No","No","No","No","Yes","Yes","Yes","No","No","Yes","No","No","Yes","No","No","Yes","Yes","Yes","No","No","No","No","No","Yes","No","No","Yes","Yes","No","Yes","Yes","Yes","Yes","No","Yes","Yes","Yes","No","Yes","Yes","No","Yes","No","No","Yes","No","No","No","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","No","No","No","Yes","No","No","Yes","No","Yes","No","No","No","No","Yes","No","No","Yes","No","No","No","No","No","No","Yes","Yes","Yes","No","No","Yes","Yes","No","No","No","No","No","No","Yes","No","No","No","No","No","Yes","No","Yes","No","Yes","Yes","No","No","No","No","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","No","No","No","No","No","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","No","No","Yes","Yes","No","No","No","Yes","No","Yes","No","No","Yes","No","No","Yes","Yes","Yes","Yes","Yes","No","Yes","No","Yes","No","Yes","Yes","No","No","Yes","No","Yes","No","Yes","No","Yes","No","No","Yes","Yes","Yes","No","No","Yes","No","Yes","No","No","No","No","No","No","Yes","Yes","No","Yes","No","Yes","No","No","No","No","Yes","No","No","Yes","Yes","No","No","No","No","Yes","No","No","No","No","No","Yes","Yes","Yes","No","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","No","No","No","Yes","Yes","Yes","No","Yes","Yes","No","No","Yes","Yes","Yes","No","No","No","Yes","No","No","No","No","No","No","Yes","Yes","Yes", ...

# %% [markdown]
# **Data Pre-Processing**
#
# ---

# %%
churn_corr = data.corr()
churn_corr_top = churn_corr.index
sns.heatmap(data[churn_corr_top].corr(), annot=True)
# Out:
# <ipython-input-12-a6e475a88cbe>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <Axes: >

# %%
# Label Encoding
categorical = data.drop(columns=['SeniorCitizen','tenure','MonthlyCharges'])
le = LabelEncoder()
for cols in categorical:
  data[cols] = le.fit_transform(data[cols])

# %%
# Scaling Numerical Features
numerical = ['SeniorCitizen','tenure','MonthlyCharges']
sc = StandardScaler()
for cols in numerical:
  data[[cols]] - sc.fit_transform(data[[cols]])

# %%
# Splitting into train and test datasets
X = data.drop(columns=['Churn'])
y = data['Churn']
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
def show_train_history(train_history,train,validation):
  plt.plot(train_history.history[train])
  plt.plot(train_history.history[validation])
  plt.title('Train History')
  plt.ylabel(train)
  plt.xlabel('Epoch')
  plt.legend(['train', 'validation'], loc='best')
  plt.show()

# %% [markdown]
# *Implementing Dropout...*

# %% [markdown]
# **Simple Deep Neural Network**
#
# ---

# %%
model1 = Sequential()
model1.add(Dense(6, kernel_initializer = 'he_uniform',activation='relu',input_dim = 19))
model1.add(Dense(6, kernel_initializer = 'he_uniform',activation='relu'))
model1.add(Dense(1, kernel_initializer = 'glorot_uniform',activation='sigmoid'))
print(model1.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 6)                 120
#
#  dense_16 (Dense)            (None, 6)                 42
#
#  dense_17 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 169 (676.00 Byte)
# Trainable params: 169 (676.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model1.compile(loss='binary_crossentropy',  optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), metrics=['accuracy'])
train_history = model1.fit(x= x_train, y=y_train,  validation_split=0.33, epochs= 100,  batch_size=50, verbose=2)
# Out:
# Epoch 1/100
# 76/76 - 2s - loss: 55.3436 - accuracy: 0.5893 - val_loss: 0.6174 - val_accuracy: 0.7333 - 2s/epoch - 21ms/step
# Epoch 2/100
# 76/76 - 0s - loss: 0.6046 - accuracy: 0.7289 - val_loss: 0.5900 - val_accuracy: 0.7360 - 333ms/epoch - 4ms/step
# Epoch 3/100
# 76/76 - 0s - loss: 0.5888 - accuracy: 0.7308 - val_loss: 0.5810 - val_accuracy: 0.7349 - 345ms/epoch - 5ms/step
# Epoch 4/100
# 76/76 - 0s - loss: 0.5836 - accuracy: 0.7308 - val_loss: 0.5781 - val_accuracy: 0.7360 - 335ms/epoch - 4ms/step
# Epoch 5/100
# 76/76 - 0s - loss: 0.5819 - accuracy: 0.7321 - val_loss: 0.5775 - val_accuracy: 0.7360 - 365ms/epoch - 5ms/step
# Epoch 6/100
# 76/76 - 0s - loss: 0.5815 - accuracy: 0.7324 - val_loss: 0.5777 - val_accuracy: 0.7371 - 379ms/epoch - 5ms/step
# Epoch 7/100
# 76/76 - 0s - loss: 0.5809 - accuracy: 0.7324 - val_loss: 0.5757 - val_accuracy: 0.7360 - 353ms/epoch - 5ms/step
# Epoch 8/100
# 76/76 - 0s - loss: 0.5806 - accuracy: 0.7329 - val_loss: 0.5778 - val_accuracy: 0.7355 - 190ms/epoch - 3ms/step
# Epoch 9/100
# 76/76 - 0s - loss: 0.5800 - accuracy: 0.7326 - val_loss: 0.5750 - val_accuracy: 0.7366 - 178ms/epoch - 2ms/step
# Epoch 10/100
# 76/76 - 0s - loss: 0.5801 - accuracy: 0.7316 - val_loss: 0.5753 - val_accuracy: 0.7371 - 187ms/epoch - 2ms/step
# Epoch 11/100
# 76/76 - 0s - loss: 0.5799 - accuracy: 0.7326 - val_loss: 0.5750 - val_accuracy: 0.7355 - 207ms/epoch - 3ms/step
# Epoch 12/100
# 76/76 - 0s - loss: 0.5797 - accuracy: 0.7329 - val_loss: 0.5746 - val_accuracy: 0.7371 - 195ms/epoch - 3ms/step
# Epoch 13/100
# 76/76 - 0s - loss: 0.5797 - accuracy: 0.7321 - val_loss: 0.5822 - val_accuracy: 0.7333 - 186ms/epoch - 2ms/step
# Epoch 14/100
# 76/76 - 0s - loss: 0.5798 - accuracy: 0.7334 - val_loss: 0.5747 - val_accuracy: 0.7366 - 186ms/epoch - 2ms/step
# Epoch 15/100
# 76/76 - 0s - loss: 0.5798 - accuracy: 0.7324 - val_loss: 0.5747 - val_accuracy: 0.7360 - 182ms/epoch - 2ms/step
# Epoch 16/100
# 76/76 - 0s - loss: 0.5796 - accuracy: 0.7329 - val_loss: 0.5762 - val_accuracy: 0.7360 - 187ms/epoch - 2ms/step
# Epoch 17/100
# 76/76 - 0s - loss: 0.5798 - accuracy: 0.7326 - val_loss: 0.5746 - val_accuracy: 0.7360 - 199ms/epoch - 3ms/step
# Epoch 18/100
# 76/76 - 0s - loss: 0.5793 - accuracy: 0.7326 - val_loss: 0.5761 - val_accuracy: 0.7360 - 198ms/epoch - 3ms/step
# Epoch 19/100
# 76/76 - 0s - loss: 0.5798 - accuracy: 0.7321 - val_loss: 0.5754 - val_accuracy: 0.7360 - 181ms/epoch - 2ms/step
# Epoch 20/100
# 76/76 - 0s - loss: 0.5807 - accuracy: 0.7326 - val_loss: 0.5746 - val_accuracy: 0.7376 - 196ms/epoch - 3ms/step
# Epoch 21/100
# 76/76 - 0s - loss: 0.5790 - accuracy: 0.7329 - val_loss: 0.5788 - val_accuracy: 0.7339 - 209ms/epoch - 3ms/step
# Epoch 22/100
# 76/76 - 0s - loss: 0.5799 - accuracy: 0.7329 - val_loss: 0.5778 - val_accuracy: 0.7349 - 201ms/epoch - 3ms/step
# Epoch 23/100
# 76/76 - 0s - loss: 0.5798 - accuracy: 0.7321 - val_loss: 0.5745 - val_accuracy: 0.7376 - 178ms/epoch - 2ms/step
# Epoch 24/100
# 76/76 - 0s - loss: 0.5795 - accuracy: 0.7321 - val_loss: 0.5842 - val_accuracy: 0.7355 - 183ms/epoch - 2ms/step
# Epoch 25/100
# 76/76 - 0s - loss: 0.5799 - accuracy: 0.7324 - val_loss: 0.5738 - val_accuracy: 0.7382 - 210ms/epoch - 3ms/step
# Epoch 26/100
# 76/76 - 0s - loss: 0.5789 - accuracy: 0.7337 - val_loss: 0.5743 - val_accuracy: 0.7376 - 205ms/epoch - 3ms/step
# Epoch 27/100
# 76/76 - 0s - loss: 0.5780 - accuracy: 0.7340 - val_loss: 0.5787 - val_accuracy: 0.7349 - 177ms/epoch - 2ms/step
# Epoch 28/100
# 76/76 - 0s - loss: 0.5779 - accuracy: 0.7345 - val_loss: 0.5744 - val_accuracy: 0.7382 - 198ms/epoch - 3ms/step
# Epoch 29/100
# 76/76 - 0s - loss: 0.5788 - accuracy: 0.7334 - val_loss: 0.5817 - val_accuracy: 0.7360 - 183ms/epoch - 2ms/step
# Epoch 30/100
# 76/76 - 0s - loss: 0.5780 - accuracy: 0.7348 - val_loss: 0.5774 - val_accuracy: 0.7349 - 191ms/epoch - 3ms/step
# Epoch 31/100
# 76/76 - 0s - loss: 0.5775 - accuracy: 0.7345 - val_loss: 0.5790 - val_accuracy: 0.7339 - 193ms/epoch - 3ms/step
# Epoch 32/100
# 76/76 - 0s - loss: 0.5767 - accuracy: 0.7358 - val_loss: 0.5740 - val_accuracy: 0.7371 - 188ms/epoch - 2ms/step
# Epoch 33/100
# 76/76 - 0s - loss: 0.5765 - accuracy: 0.7361 - val_loss: 0.5860 - val_accuracy: 0.7360 - 190ms/epoch - 3ms/step
# Epoch 34/100
# 76/76 - 0s - loss: 0.5769 - accuracy: 0.7348 - val_loss: 0.5743 - val_accuracy: 0.7376 - 198ms/epoch - 3ms/step
# Epoch 35/100
# 76/76 - 0s - loss: 0.5769 - accuracy: 0.7340 - val_loss: 0.5743 - val_accuracy: 0.7382 - 197ms/epoch - 3ms/step
# Epoch 36/100
# 76/76 - 0s - loss: 0.5787 - accuracy: 0.7334 - val_loss: 0.5748 - val_accuracy: 0.7366 - 198ms/epoch - 3ms/step
# Epoch 37/100
# 76/76 - 0s - loss: 0.5764 - accuracy: 0.7350 - val_loss: 0.5748 - val_accuracy: 0.7371 - 199ms/epoch - 3ms/step
# Epoch 38/100
# 76/76 - 0s - loss: 0.5777 - accuracy: 0.7342 - val_loss: 0.5776 - val_accuracy: 0.7366 - 202ms/epoch - 3ms/step
# Epoch 39/100
# 76/76 - 0s - loss: 0.5799 - accuracy: 0.7340 - val_loss: 0.5753 - val_accuracy: 0.7366 - 206ms/epoch - 3ms/step
# Epoch 40/100
# 76/76 - 0s - loss: 0.5819 - accuracy: 0.7305 - val_loss: 0.5748 - val_accuracy: 0.7371 - 199ms/epoch - 3ms/step
# Epoch 41/100
# 76/76 - 0s - loss: 0.5809 - accuracy: 0.7303 - val_loss: 0.5742 - val_accuracy: 0.7371 - 198ms/epoch - 3ms/step
# Epoch 42/100
# 76/76 - 0s - loss: 0.5814 - accuracy: 0.7300 - val_loss: 0.5743 - val_accuracy: 0.7360 - 198ms/epoch - 3ms/step
# Epoch 43/100
# 76/76 - 0s - loss: 0.5804 - accuracy: 0.7305 - val_loss: 0.5756 - val_accuracy: 0.7349 - 199ms/epoch - 3ms/step
# Epoch 44/100
# 76/76 - 0s - loss: 0.5791 - accuracy: 0.7308 - val_loss: 0.5770 - val_accuracy: 0.7355 - 197ms/epoch - 3ms/step
# Epoch 45/100
# 76/76 - 0s - loss: 0.5810 - accuracy: 0.7321 - val_loss: 0.5769 - val_accuracy: 0.7344 - 200ms/epoch - 3ms/step
# Epoch 46/100
# 76/76 - 0s - loss: 0.5801 - accuracy: 0.7303 - val_loss: 0.5758 - val_accuracy: 0.7328 - 183ms/epoch - 2ms/step
# Epoch 47/100
# 76/76 - 0s - loss: 0.5791 - accuracy: 0.7316 - val_loss: 0.5758 - val_accuracy: 0.7333 - 202ms/epoch - 3ms/step
# Epoch 48/100
# 76/76 - 0s - loss: 0.5789 - accuracy: 0.7311 - val_loss: 0.5749 - val_accuracy: 0.7349 - 181ms/epoch - 2ms/step
# Epoch 49/100
# 76/76 - 0s - loss: 0.5782 - accuracy: 0.7326 - val_loss: 0.5749 - val_accuracy: 0.7355 - 205ms/epoch - 3ms/step
# Epoch 50/100
# 76/76 - 0s - loss: 0.5776 - accuracy: 0.7332 - val_loss: 0.5773 - val_accuracy: 0.7349 - 197ms/epoch - 3ms/step
# Epoch 51/100
# 76/76 - 0s - loss: 0.5783 - accuracy: 0.7324 - val_loss: 0.5743 - val_accuracy: 0.7376 - 186ms/epoch - 2ms/step
# Epoch 52/100
# 76/76 - 0s - loss: 0.5795 - accuracy: 0.7324 - val_loss: 0.5743 - val_accuracy: 0.7366 - 208ms/epoch - 3ms/step
# Epoch 53/100
# 76/76 - 0s - loss: 0.5776 - accuracy: 0.7345 - val_loss: 0.5766 - val_accuracy: 0.7344 - 198ms/epoch - 3ms/step
# Epoch 54/100
# 76/76 - 0s - loss: 0.5766 - accuracy: 0.7345 - val_loss: 0.5759 - val_accuracy: 0.7366 - 319ms/epoch - 4ms/step
# Epoch 55/100
# 76/76 - 0s - loss: 0.5817 - accuracy: 0.7337 - val_loss: 0.5763 - val_accuracy: 0.7328 - 391ms/epoch - 5ms/step
# Epoch 56/100
# 76/76 - 1s - loss: 0.5767 - accuracy: 0.7345 - val_loss: 0.5787 - val_accuracy: 0.7349 - 727ms/epoch - 10ms/step
# Epoch 57/100
# 76/76 - 1s - loss: 0.5803 - accuracy: 0.7321 - val_loss: 0.5752 - val_accuracy: 0.7360 - 833ms/epoch - 11ms/step
# Epoch 58/100
# 76/76 - 1s - loss: 0.5790 - accuracy: 0.7316 - val_loss: 0.5765 - val_accuracy: 0.7339 - 803ms/epoch - 11ms/step
# Epoch 59/100
# 76/76 - 1s - loss: 0.5786 - accuracy: 0.7321 - val_loss: 0.5737 - val_accuracy: 0.7371 - 783ms/epoch - 10ms/step
# Epoch 60/100
# 76/76 - 0s - loss: 0.5791 - accuracy: 0.7311 - val_loss: 0.5740 - val_accuracy: 0.7360 - 498ms/epoch - 7ms/step
# Epoch 61/100
# 76/76 - 0s - loss: 0.5778 - accuracy: 0.7324 - val_loss: 0.5778 - val_accuracy: 0.7349 - 491ms/epoch - 6ms/step
# Epoch 62/100
# 76/76 - 0s - loss: 0.5786 - accuracy: 0.7340 - val_loss: 0.5741 - val_accuracy: 0.7376 - 251ms/epoch - 3ms/step
# Epoch 63/100
# 76/76 - 0s - loss: 0.5766 - accuracy: 0.7332 - val_loss: 0.5741 - val_accuracy: 0.7371 - 207ms/epoch - 3ms/step
# Epoch 64/100
# 76/76 - 0s - loss: 0.5761 - accuracy: 0.7334 - val_loss: 0.5742 - val_accuracy: 0.7387 - 186ms/epoch - 2ms/step
# Epoch 65/100
# 76/76 - 0s - loss: 0.5747 - accuracy: 0.7358 - val_loss: 0.5825 - val_accuracy: 0.7403 - 193ms/epoch - 3ms/step
# Epoch 66/100
# 76/76 - 0s - loss: 0.5783 - accuracy: 0.7332 - val_loss: 0.5745 - val_accuracy: 0.7355 - 209ms/epoch - 3ms/step
# Epoch 67/100
# 76/76 - 0s - loss: 0.5764 - accuracy: 0.7350 - val_loss: 0.5802 - val_accuracy: 0.7355 - 203ms/epoch - 3ms/step
# Epoch 68/100
# 76/76 - 0s - loss: 0.5754 - accuracy: 0.7358 - val_loss: 0.5742 - val_accuracy: 0.7360 - 201ms/epoch - 3ms/step
# Epoch 69/100
# 76/76 - 0s - loss: 0.5757 - accuracy: 0.7348 - val_loss: 0.5784 - val_accuracy: 0.7366 - 176ms/epoch - 2ms/step
# Epoch 70/100
# 76/76 - 0s - loss: 0.5755 - accuracy: 0.7366 - val_loss: 0.5748 - val_accuracy: 0.7355 - 194ms/epoch - 3ms/step
# Epoch 71/100
# 76/76 - 0s - loss: 0.5744 - accuracy: 0.7356 - val_loss: 0.5749 - val_accuracy: 0.7366 - 195ms/epoch - 3ms/step
# Epoch 72/100
# 76/76 - 0s - loss: 0.5737 - accuracy: 0.7361 - val_loss: 0.5742 - val_accuracy: 0.7366 - 198ms/epoch - 3ms/step
# Epoch 73/100
# 76/76 - 0s - loss: 0.5794 - accuracy: 0.7340 - val_loss: 0.5744 - val_accuracy: 0.7382 - 183ms/epoch - 2ms/step
# Epoch 74/100
# 76/76 - 0s - loss: 0.5772 - accuracy: 0.7326 - val_loss: 0.5739 - val_accuracy: 0.7366 - 179ms/epoch - 2ms/step
# Epoch 75/100
# 76/76 - 0s - loss: 0.5756 - accuracy: 0.7332 - val_loss: 0.5743 - val_accuracy: 0.7376 - 197ms/epoch - 3ms/step
# Epoch 76/100
# 76/76 - 0s - loss: 0.5752 - accuracy: 0.7356 - val_loss: 0.5744 - val_accuracy: 0.7376 - 198ms/epoch - 3ms/step
# Epoch 77/100
# 76/76 - 0s - loss: 0.5742 - accuracy: 0.7353 - val_loss: 0.5841 - val_accuracy: 0.7360 - 185ms/epoch - 2ms/step
# Epoch 78/100
# 76/76 - 0s - loss: 0.5749 - accuracy: 0.7353 - val_loss: 0.5750 - val_accuracy: 0.7376 - 183ms/epoch - 2ms/step
# Epoch 79/100
# 76/76 - 0s - loss: 0.5750 - accuracy: 0.7358 - val_loss: 0.5813 - val_accuracy: 0.7366 - 180ms/epoch - 2ms/step
# Epoch 80/100
# 76/76 - 0s - loss: 0.5776 - accuracy: 0.7350 - val_loss: 0.5856 - val_accuracy: 0.7333 - 201ms/epoch - 3ms/step
# Epoch 81/100
# 76/76 - 0s - loss: 0.5758 - accuracy: 0.7350 - val_loss: 0.5741 - val_accuracy: 0.7387 - 202ms/epoch - 3ms/step
# Epoch 82/100
# 76/76 - 0s - loss: 0.5768 - accuracy: 0.7340 - val_loss: 0.5750 - val_accuracy: 0.7376 - 205ms/epoch - 3ms/step
# Epoch 83/100
# 76/76 - 0s - loss: 0.5748 - accuracy: 0.7353 - val_loss: 0.5807 - val_accuracy: 0.7360 - 182ms/epoch - 2ms/step
# Epoch 84/100
# 76/76 - 0s - loss: 0.5746 - accuracy: 0.7366 - val_loss: 0.5754 - val_accuracy: 0.7366 - 204ms/epoch - 3ms/step
# Epoch 85/100
# 76/76 - 0s - loss: 0.5743 - accuracy: 0.7364 - val_loss: 0.5763 - val_accuracy: 0.7360 - 196ms/epoch - 3ms/step
# Epoch 86/100
# 76/76 - 0s - loss: 0.5734 - accuracy: 0.7366 - val_loss: 0.5739 - val_accuracy: 0.7371 - 200ms/epoch - 3ms/step
# Epoch 87/100
# 76/76 - 0s - loss: 0.5731 - accuracy: 0.7364 - val_loss: 0.5863 - val_accuracy: 0.7344 - 198ms/epoch - 3ms/step
# Epoch 88/100
# 76/76 - 0s - loss: 0.5744 - accuracy: 0.7356 - val_loss: 0.5761 - val_accuracy: 0.7371 - 180ms/epoch - 2ms/step
# Epoch 89/100
# 76/76 - 0s - loss: 0.5728 - accuracy: 0.7358 - val_loss: 0.5752 - val_accuracy: 0.7376 - 194ms/epoch - 3ms/step
# Epoch 90/100
# 76/76 - 0s - loss: 0.5721 - accuracy: 0.7377 - val_loss: 0.5737 - val_accuracy: 0.7387 - 199ms/epoch - 3ms/step
# Epoch 91/100
# 76/76 - 0s - loss: 0.5733 - accuracy: 0.7366 - val_loss: 0.5780 - val_accuracy: 0.7344 - 199ms/epoch - 3ms/step
# Epoch 92/100
# 76/76 - 0s - loss: 0.5751 - accuracy: 0.7350 - val_loss: 0.5727 - val_accuracy: 0.7392 - 205ms/epoch - 3ms/step
# Epoch 93/100
# 76/76 - 0s - loss: 0.5745 - accuracy: 0.7334 - val_loss: 0.5828 - val_accuracy: 0.7360 - 200ms/epoch - 3ms/step
# Epoch 94/100
# 76/76 - 0s - loss: 0.5734 - accuracy: 0.7369 - val_loss: 0.5772 - val_accuracy: 0.7376 - 197ms/epoch - 3ms/step
# Epoch 95/100
# 76/76 - 0s - loss: 0.5741 - accuracy: 0.7369 - val_loss: 0.5871 - val_accuracy: 0.7339 - 185ms/epoch - 2ms/step
# Epoch 96/100
# 76/76 - 0s - loss: 0.5788 - accuracy: 0.7332 - val_loss: 0.5971 - val_accuracy: 0.7301 - 197ms/epoch - 3ms/step
# Epoch 97/100
# 76/76 - 0s - loss: 0.5729 - accuracy: 0.7366 - val_loss: 0.5736 - val_accuracy: 0.7382 - 204ms/epoch - 3ms/step
# Epoch 98/100
# 76/76 - 0s - loss: 0.5729 - accuracy: 0.7374 - val_loss: 0.5750 - val_accuracy: 0.7371 - 205ms/epoch - 3ms/step
# Epoch 99/100
# 76/76 - 0s - loss: 0.5725 - accuracy: 0.7374 - val_loss: 0.5845 - val_accuracy: 0.7349 - 179ms/epoch - 2ms/step
# Epoch 100/100
# 76/76 - 0s - loss: 0.5727 - accuracy: 0.7387 - val_loss: 0.5823 - val_accuracy: 0.7339 - 179ms/epoch - 2ms/step

# %%
show_train_history(train_history,'accuracy','val_accuracy')
show_train_history(train_history,'loss','val_loss')

# %%
scores = model1.evaluate(x_test, y_test)
print('\n')
print('accuracy=',scores[1])
# Out:
# 45/45 [==============================] - 0s 1ms/step - loss: 0.5576 - accuracy: 0.7509
#
#
# accuracy= 0.7508871555328369

# %%
y_pred1 = model1.predict(x_test)
accuracy1 = accuracy_score(y_test, np.argmax(y_pred1, axis=1))
f11 = f1_score(y_test, np.argmax(y_pred1, axis=1))
roc_auc1 = roc_auc_score(tf.keras.utils.to_categorical(y_test), y_pred1)
# Out:
# 45/45 [==============================] - 0s 1ms/step

# %%
y_pred1 = (y_pred1 > 0.5)
y_pred1
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
cm = confusion_matrix(y_pred1,y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.ylabel('Predicted')
plt.xlabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.99      0.85      1045
#            1       0.66      0.07      0.13       364
#
#     accuracy                           0.75      1409
#    macro avg       0.71      0.53      0.49      1409
# weighted avg       0.73      0.75      0.67      1409

# %% [markdown]
# **Deep Neural Network with Dropout**
#
# ---

# %%
model2 = Sequential()
model2.add(Dense(1028, kernel_initializer = 'he_uniform',activation='relu',input_dim = 19))
model2.add(Dropout(0.5))
model2.add(Dense(514, kernel_initializer = 'he_uniform',activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(1, kernel_initializer = 'glorot_uniform',activation='sigmoid'))
print(model2.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 1028)              20560
#
#  dropout_6 (Dropout)         (None, 1028)              0
#
#  dense_13 (Dense)            (None, 514)               528906
#
#  dropout_7 (Dropout)         (None, 514)               0
#
#  dense_14 (Dense)            (None, 1)                 515
#
# =================================================================
# Total params: 549981 (2.10 MB)
# Trainable params: 549981 (2.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model2.compile(loss='binary_crossentropy',  optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), metrics=['accuracy'])
train_history = model2.fit(x= x_train, y=y_train,  validation_split=0.33, epochs= 100,  batch_size=50, verbose=2)
# Out:
# Epoch 1/100
# 76/76 - 6s - loss: 928.0839 - accuracy: 0.5978 - val_loss: 0.6181 - val_accuracy: 0.7371 - 6s/epoch - 73ms/step
# Epoch 2/100
# 76/76 - 2s - loss: 0.9069 - accuracy: 0.6958 - val_loss: 0.6071 - val_accuracy: 0.7371 - 2s/epoch - 29ms/step
# Epoch 3/100
# 76/76 - 1s - loss: 0.6996 - accuracy: 0.7173 - val_loss: 0.5925 - val_accuracy: 0.7366 - 1s/epoch - 14ms/step
# Epoch 4/100
# 76/76 - 1s - loss: 0.6154 - accuracy: 0.7266 - val_loss: 0.5808 - val_accuracy: 0.7371 - 904ms/epoch - 12ms/step
# Epoch 5/100
# 76/76 - 1s - loss: 0.6176 - accuracy: 0.7260 - val_loss: 0.5759 - val_accuracy: 0.7371 - 915ms/epoch - 12ms/step
# Epoch 6/100
# 76/76 - 1s - loss: 0.5957 - accuracy: 0.7260 - val_loss: 0.5760 - val_accuracy: 0.7371 - 946ms/epoch - 12ms/step
# Epoch 7/100
# 76/76 - 1s - loss: 0.5957 - accuracy: 0.7281 - val_loss: 0.5776 - val_accuracy: 0.7371 - 868ms/epoch - 11ms/step
# Epoch 8/100
# 76/76 - 1s - loss: 0.5867 - accuracy: 0.7292 - val_loss: 0.5749 - val_accuracy: 0.7371 - 896ms/epoch - 12ms/step
# Epoch 9/100
# 76/76 - 1s - loss: 0.6027 - accuracy: 0.7297 - val_loss: 0.5749 - val_accuracy: 0.7371 - 917ms/epoch - 12ms/step
# Epoch 10/100
# 76/76 - 1s - loss: 0.5892 - accuracy: 0.7289 - val_loss: 0.5761 - val_accuracy: 0.7371 - 1s/epoch - 19ms/step
# Epoch 11/100
# 76/76 - 1s - loss: 0.5936 - accuracy: 0.7297 - val_loss: 0.5740 - val_accuracy: 0.7371 - 1s/epoch - 13ms/step
# Epoch 12/100
# 76/76 - 1s - loss: 0.5897 - accuracy: 0.7287 - val_loss: 0.5743 - val_accuracy: 0.7371 - 845ms/epoch - 11ms/step
# Epoch 13/100
# 76/76 - 1s - loss: 0.5935 - accuracy: 0.7297 - val_loss: 0.5732 - val_accuracy: 0.7371 - 860ms/epoch - 11ms/step
# Epoch 14/100
# 76/76 - 1s - loss: 0.5865 - accuracy: 0.7284 - val_loss: 0.5746 - val_accuracy: 0.7371 - 837ms/epoch - 11ms/step
# Epoch 15/100
# 76/76 - 1s - loss: 0.5818 - accuracy: 0.7311 - val_loss: 0.5746 - val_accuracy: 0.7371 - 878ms/epoch - 12ms/step
# Epoch 16/100
# 76/76 - 1s - loss: 0.5827 - accuracy: 0.7292 - val_loss: 0.5741 - val_accuracy: 0.7371 - 904ms/epoch - 12ms/step
# Epoch 17/100
# 76/76 - 1s - loss: 0.5939 - accuracy: 0.7289 - val_loss: 0.5745 - val_accuracy: 0.7371 - 836ms/epoch - 11ms/step
# Epoch 18/100
# 76/76 - 1s - loss: 0.6208 - accuracy: 0.7300 - val_loss: 0.5745 - val_accuracy: 0.7371 - 842ms/epoch - 11ms/step
# Epoch 19/100
# 76/76 - 1s - loss: 0.5800 - accuracy: 0.7316 - val_loss: 0.5747 - val_accuracy: 0.7366 - 814ms/epoch - 11ms/step
# Epoch 20/100
# 76/76 - 1s - loss: 0.5793 - accuracy: 0.7305 - val_loss: 0.5732 - val_accuracy: 0.7355 - 891ms/epoch - 12ms/step
# Epoch 21/100
# 76/76 - 1s - loss: 0.5897 - accuracy: 0.7308 - val_loss: 0.5743 - val_accuracy: 0.7371 - 935ms/epoch - 12ms/step
# Epoch 22/100
# 76/76 - 1s - loss: 0.5947 - accuracy: 0.7305 - val_loss: 0.5739 - val_accuracy: 0.7371 - 1s/epoch - 14ms/step
# Epoch 23/100
# 76/76 - 2s - loss: 0.5829 - accuracy: 0.7313 - val_loss: 0.5732 - val_accuracy: 0.7382 - 2s/epoch - 26ms/step
# Epoch 24/100
# 76/76 - 2s - loss: 0.5874 - accuracy: 0.7305 - val_loss: 0.5740 - val_accuracy: 0.7371 - 2s/epoch - 24ms/step
# Epoch 25/100
# 76/76 - 2s - loss: 0.6078 - accuracy: 0.7303 - val_loss: 0.5741 - val_accuracy: 0.7371 - 2s/epoch - 21ms/step
# Epoch 26/100
# 76/76 - 1s - loss: 0.5870 - accuracy: 0.7311 - val_loss: 0.5740 - val_accuracy: 0.7371 - 1s/epoch - 18ms/step
# Epoch 27/100
# 76/76 - 1s - loss: 0.6331 - accuracy: 0.7289 - val_loss: 0.5744 - val_accuracy: 0.7371 - 1s/epoch - 20ms/step
# Epoch 28/100
# 76/76 - 1s - loss: 0.5919 - accuracy: 0.7303 - val_loss: 0.5766 - val_accuracy: 0.7371 - 1s/epoch - 19ms/step
# Epoch 29/100
# 76/76 - 2s - loss: 0.5932 - accuracy: 0.7284 - val_loss: 0.5738 - val_accuracy: 0.7366 - 2s/epoch - 20ms/step
# Epoch 30/100
# 76/76 - 2s - loss: 0.5943 - accuracy: 0.7308 - val_loss: 0.5736 - val_accuracy: 0.7371 - 2s/epoch - 20ms/step
# Epoch 31/100
# 76/76 - 3s - loss: 0.5820 - accuracy: 0.7308 - val_loss: 0.5735 - val_accuracy: 0.7371 - 3s/epoch - 34ms/step
# Epoch 32/100
# 76/76 - 1s - loss: 0.5940 - accuracy: 0.7297 - val_loss: 0.5743 - val_accuracy: 0.7371 - 837ms/epoch - 11ms/step
# Epoch 33/100
# 76/76 - 1s - loss: 0.5802 - accuracy: 0.7318 - val_loss: 0.5736 - val_accuracy: 0.7371 - 886ms/epoch - 12ms/step
# Epoch 34/100
# 76/76 - 1s - loss: 0.5808 - accuracy: 0.7311 - val_loss: 0.5749 - val_accuracy: 0.7371 - 914ms/epoch - 12ms/step
# Epoch 35/100
# 76/76 - 1s - loss: 0.5843 - accuracy: 0.7316 - val_loss: 0.5726 - val_accuracy: 0.7371 - 865ms/epoch - 11ms/step
# Epoch 36/100
# 76/76 - 1s - loss: 0.5785 - accuracy: 0.7334 - val_loss: 0.5727 - val_accuracy: 0.7376 - 842ms/epoch - 11ms/step
# Epoch 37/100
# 76/76 - 1s - loss: 0.5858 - accuracy: 0.7297 - val_loss: 0.5758 - val_accuracy: 0.7371 - 896ms/epoch - 12ms/step
# Epoch 38/100
# 76/76 - 1s - loss: 0.5808 - accuracy: 0.7313 - val_loss: 0.5750 - val_accuracy: 0.7392 - 827ms/epoch - 11ms/step
# Epoch 39/100
# 76/76 - 1s - loss: 0.5890 - accuracy: 0.7289 - val_loss: 0.5745 - val_accuracy: 0.7371 - 873ms/epoch - 11ms/step
# Epoch 40/100
# 76/76 - 1s - loss: 0.5815 - accuracy: 0.7318 - val_loss: 0.5737 - val_accuracy: 0.7371 - 845ms/epoch - 11ms/step
# Epoch 41/100
# 76/76 - 1s - loss: 0.5815 - accuracy: 0.7321 - val_loss: 0.5732 - val_accuracy: 0.7371 - 832ms/epoch - 11ms/step
# Epoch 42/100
# 76/76 - 1s - loss: 0.5846 - accuracy: 0.7321 - val_loss: 0.5728 - val_accuracy: 0.7371 - 844ms/epoch - 11ms/step
# Epoch 43/100
# 76/76 - 1s - loss: 0.5801 - accuracy: 0.7311 - val_loss: 0.5725 - val_accuracy: 0.7392 - 1s/epoch - 16ms/step
# Epoch 44/100
# 76/76 - 1s - loss: 0.5766 - accuracy: 0.7345 - val_loss: 0.5729 - val_accuracy: 0.7371 - 1s/epoch - 19ms/step
# Epoch 45/100
# 76/76 - 1s - loss: 0.5753 - accuracy: 0.7324 - val_loss: 0.5744 - val_accuracy: 0.7371 - 843ms/epoch - 11ms/step
# Epoch 46/100
# 76/76 - 1s - loss: 0.6022 - accuracy: 0.7308 - val_loss: 0.5727 - val_accuracy: 0.7371 - 893ms/epoch - 12ms/step
# Epoch 47/100
# 76/76 - 1s - loss: 0.5804 - accuracy: 0.7332 - val_loss: 0.5716 - val_accuracy: 0.7387 - 875ms/epoch - 12ms/step
# Epoch 48/100
# 76/76 - 1s - loss: 0.5813 - accuracy: 0.7342 - val_loss: 0.5758 - val_accuracy: 0.7371 - 854ms/epoch - 11ms/step
# Epoch 49/100
# 76/76 - 1s - loss: 0.5802 - accuracy: 0.7303 - val_loss: 0.5740 - val_accuracy: 0.7371 - 816ms/epoch - 11ms/step
# Epoch 50/100
# 76/76 - 1s - loss: 0.5840 - accuracy: 0.7313 - val_loss: 0.5722 - val_accuracy: 0.7398 - 818ms/epoch - 11ms/step
# Epoch 51/100
# 76/76 - 1s - loss: 0.5780 - accuracy: 0.7305 - val_loss: 0.5722 - val_accuracy: 0.7382 - 835ms/epoch - 11ms/step
# Epoch 52/100
# 76/76 - 1s - loss: 0.5789 - accuracy: 0.7326 - val_loss: 0.5739 - val_accuracy: 0.7371 - 874ms/epoch - 12ms/step
# Epoch 53/100
# 76/76 - 1s - loss: 0.5824 - accuracy: 0.7321 - val_loss: 0.5901 - val_accuracy: 0.7403 - 832ms/epoch - 11ms/step
# Epoch 54/100
# 76/76 - 1s - loss: 0.6096 - accuracy: 0.7297 - val_loss: 0.5743 - val_accuracy: 0.7371 - 849ms/epoch - 11ms/step
# Epoch 55/100
# 76/76 - 1s - loss: 0.5839 - accuracy: 0.7300 - val_loss: 0.5739 - val_accuracy: 0.7371 - 899ms/epoch - 12ms/step
# Epoch 56/100
# 76/76 - 1s - loss: 0.5955 - accuracy: 0.7300 - val_loss: 0.5734 - val_accuracy: 0.7371 - 1s/epoch - 16ms/step
# Epoch 57/100
# 76/76 - 2s - loss: 0.6038 - accuracy: 0.7303 - val_loss: 0.5745 - val_accuracy: 0.7371 - 2s/epoch - 20ms/step
# Epoch 58/100
# 76/76 - 1s - loss: 0.5792 - accuracy: 0.7337 - val_loss: 0.5720 - val_accuracy: 0.7398 - 914ms/epoch - 12ms/step
# Epoch 59/100
# 76/76 - 1s - loss: 0.5834 - accuracy: 0.7324 - val_loss: 0.5738 - val_accuracy: 0.7371 - 900ms/epoch - 12ms/step
# Epoch 60/100
# 76/76 - 1s - loss: 0.5841 - accuracy: 0.7311 - val_loss: 0.5717 - val_accuracy: 0.7392 - 890ms/epoch - 12ms/step
# Epoch 61/100
# 76/76 - 1s - loss: 0.5798 - accuracy: 0.7313 - val_loss: 0.5725 - val_accuracy: 0.7398 - 864ms/epoch - 11ms/step
# Epoch 62/100
# 76/76 - 1s - loss: 0.5854 - accuracy: 0.7305 - val_loss: 0.5754 - val_accuracy: 0.7371 - 901ms/epoch - 12ms/step
# Epoch 63/100
# 76/76 - 1s - loss: 0.5830 - accuracy: 0.7313 - val_loss: 0.5776 - val_accuracy: 0.7371 - 857ms/epoch - 11ms/step
# Epoch 64/100
# 76/76 - 1s - loss: 0.5807 - accuracy: 0.7332 - val_loss: 0.5755 - val_accuracy: 0.7371 - 874ms/epoch - 12ms/step
# Epoch 65/100
# 76/76 - 1s - loss: 0.5807 - accuracy: 0.7308 - val_loss: 0.5814 - val_accuracy: 0.7371 - 809ms/epoch - 11ms/step
# Epoch 66/100
# 76/76 - 1s - loss: 0.5832 - accuracy: 0.7305 - val_loss: 0.5747 - val_accuracy: 0.7382 - 826ms/epoch - 11ms/step
# Epoch 67/100
# 76/76 - 1s - loss: 0.5803 - accuracy: 0.7311 - val_loss: 0.5737 - val_accuracy: 0.7376 - 878ms/epoch - 12ms/step
# Epoch 68/100
# 76/76 - 1s - loss: 0.5835 - accuracy: 0.7300 - val_loss: 0.5758 - val_accuracy: 0.7371 - 855ms/epoch - 11ms/step
# Epoch 69/100
# 76/76 - 1s - loss: 0.5791 - accuracy: 0.7311 - val_loss: 0.5762 - val_accuracy: 0.7376 - 1s/epoch - 17ms/step
# Epoch 70/100
# 76/76 - 1s - loss: 0.5951 - accuracy: 0.7305 - val_loss: 0.5739 - val_accuracy: 0.7387 - 1s/epoch - 17ms/step
# Epoch 71/100
# 76/76 - 1s - loss: 0.5805 - accuracy: 0.7321 - val_loss: 0.5733 - val_accuracy: 0.7376 - 852ms/epoch - 11ms/step
# Epoch 72/100
# 76/76 - 1s - loss: 0.5774 - accuracy: 0.7313 - val_loss: 0.5734 - val_accuracy: 0.7382 - 851ms/epoch - 11ms/step
# Epoch 73/100
# 76/76 - 1s - loss: 0.5805 - accuracy: 0.7313 - val_loss: 0.5742 - val_accuracy: 0.7392 - 820ms/epoch - 11ms/step
# Epoch 74/100
# 76/76 - 1s - loss: 0.5841 - accuracy: 0.7321 - val_loss: 0.5757 - val_accuracy: 0.7371 - 877ms/epoch - 12ms/step
# Epoch 75/100
# 76/76 - 1s - loss: 0.5815 - accuracy: 0.7318 - val_loss: 0.5745 - val_accuracy: 0.7371 - 891ms/epoch - 12ms/step
# Epoch 76/100
# 76/76 - 1s - loss: 0.5812 - accuracy: 0.7329 - val_loss: 0.5745 - val_accuracy: 0.7371 - 874ms/epoch - 11ms/step
# Epoch 77/100
# 76/76 - 1s - loss: 0.5964 - accuracy: 0.7313 - val_loss: 0.5770 - val_accuracy: 0.7382 - 813ms/epoch - 11ms/step
# Epoch 78/100
# 76/76 - 1s - loss: 0.5854 - accuracy: 0.7313 - val_loss: 0.5773 - val_accuracy: 0.7398 - 777ms/epoch - 10ms/step
# Epoch 79/100
# 76/76 - 1s - loss: 0.5814 - accuracy: 0.7332 - val_loss: 0.5773 - val_accuracy: 0.7371 - 805ms/epoch - 11ms/step
# Epoch 80/100
# 76/76 - 1s - loss: 0.5829 - accuracy: 0.7308 - val_loss: 0.5770 - val_accuracy: 0.7371 - 799ms/epoch - 11ms/step
# Epoch 81/100
# 76/76 - 1s - loss: 0.5791 - accuracy: 0.7321 - val_loss: 0.5763 - val_accuracy: 0.7382 - 846ms/epoch - 11ms/step
# Epoch 82/100
# 76/76 - 1s - loss: 0.5784 - accuracy: 0.7332 - val_loss: 0.5760 - val_accuracy: 0.7392 - 1s/epoch - 14ms/step
# Epoch 83/100
# 76/76 - 1s - loss: 0.5839 - accuracy: 0.7316 - val_loss: 0.5760 - val_accuracy: 0.7371 - 1s/epoch - 19ms/step
# Epoch 84/100
# 76/76 - 1s - loss: 0.5842 - accuracy: 0.7313 - val_loss: 0.5765 - val_accuracy: 0.7371 - 933ms/epoch - 12ms/step
# Epoch 85/100
# 76/76 - 1s - loss: 0.5808 - accuracy: 0.7316 - val_loss: 0.5752 - val_accuracy: 0.7371 - 846ms/epoch - 11ms/step
# Epoch 86/100
# 76/76 - 1s - loss: 0.6469 - accuracy: 0.7305 - val_loss: 0.5771 - val_accuracy: 0.7371 - 872ms/epoch - 11ms/step
# Epoch 87/100
# 76/76 - 1s - loss: 0.6256 - accuracy: 0.7300 - val_loss: 0.5777 - val_accuracy: 0.7371 - 839ms/epoch - 11ms/step
# Epoch 88/100
# 76/76 - 1s - loss: 0.5808 - accuracy: 0.7308 - val_loss: 0.5781 - val_accuracy: 0.7371 - 865ms/epoch - 11ms/step
# Epoch 89/100
# 76/76 - 1s - loss: 0.5859 - accuracy: 0.7300 - val_loss: 0.5778 - val_accuracy: 0.7371 - 815ms/epoch - 11ms/step
# Epoch 90/100
# 76/76 - 1s - loss: 0.6159 - accuracy: 0.7316 - val_loss: 0.5771 - val_accuracy: 0.7376 - 846ms/epoch - 11ms/step
# Epoch 91/100
# 76/76 - 1s - loss: 0.5808 - accuracy: 0.7303 - val_loss: 0.5780 - val_accuracy: 0.7371 - 885ms/epoch - 12ms/step
# Epoch 92/100
# 76/76 - 1s - loss: 0.5809 - accuracy: 0.7308 - val_loss: 0.5799 - val_accuracy: 0.7371 - 849ms/epoch - 11ms/step
# Epoch 93/100
# 76/76 - 1s - loss: 0.5806 - accuracy: 0.7305 - val_loss: 0.5754 - val_accuracy: 0.7371 - 856ms/epoch - 11ms/step
# Epoch 94/100
# 76/76 - 1s - loss: 0.5798 - accuracy: 0.7313 - val_loss: 0.5758 - val_accuracy: 0.7371 - 805ms/epoch - 11ms/step
# Epoch 95/100
# 76/76 - 1s - loss: 0.6105 - accuracy: 0.7308 - val_loss: 0.5749 - val_accuracy: 0.7371 - 1s/epoch - 14ms/step
# Epoch 96/100
# 76/76 - 2s - loss: 0.6667 - accuracy: 0.7313 - val_loss: 0.5774 - val_accuracy: 0.7371 - 2s/epoch - 20ms/step
# Epoch 97/100
# 76/76 - 1s - loss: 0.6014 - accuracy: 0.7313 - val_loss: 0.5723 - val_accuracy: 0.7392 - 939ms/epoch - 12ms/step
# Epoch 98/100
# 76/76 - 1s - loss: 0.5869 - accuracy: 0.7311 - val_loss: 0.5759 - val_accuracy: 0.7371 - 824ms/epoch - 11ms/step
# Epoch 99/100
# 76/76 - 1s - loss: 0.5821 - accuracy: 0.7308 - val_loss: 0.5758 - val_accuracy: 0.7371 - 867ms/epoch - 11ms/step
# Epoch 100/100
# 76/76 - 1s - loss: 0.5802 - accuracy: 0.7316 - val_loss: 0.5753 - val_accuracy: 0.7376 - 881ms/epoch - 12ms/step

# %%
show_train_history(train_history,'accuracy','val_accuracy')
show_train_history(train_history,'loss','val_loss')

# %%
scores = model2.evaluate(x_test, y_test)
print('\n')
print('accuracy=',scores[1])
# Out:
# 45/45 [==============================] - 0s 3ms/step - loss: 0.5687 - accuracy: 0.7431
#
#
# accuracy= 0.743080198764801

# %%
y_pred2 = model2.predict(x_test)
accuracy2 = accuracy_score(y_test, np.argmax(y_pred2, axis=1))
f12 = f1_score(y_test, np.argmax(y_pred2, axis=1))
roc_auc2 = roc_auc_score(tf.keras.utils.to_categorical(y_test), y_pred2)
# Out:
# 45/45 [==============================] - 0s 2ms/step

# %%
y_pred2 = (y_pred2 > 0.5)
y_pred2
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
cm = confusion_matrix(y_pred2,y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('True')
plt.ylabel('Predicted')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85      1045
#            1       1.00      0.01      0.01       364
#
#     accuracy                           0.74      1409
#    macro avg       0.87      0.50      0.43      1409
# weighted avg       0.81      0.74      0.63      1409

# %% [markdown]
# *Implementing Layer-wise Dropout...*

# %%
model3 = Sequential()
model3.add(Dense(1028, kernel_initializer = 'he_uniform',activation='relu',input_dim = 19))
model3.add(Dropout(0.3))
model3.add(Dense(514, kernel_initializer = 'he_uniform',activation='relu'))
model3.add(Dropout(0.2))
model3.add(Dense(1, kernel_initializer = 'glorot_uniform',activation='sigmoid'))
print(model3.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 1028)              20560
#
#  dropout_4 (Dropout)         (None, 1028)              0
#
#  dense_10 (Dense)            (None, 514)               528906
#
#  dropout_5 (Dropout)         (None, 514)               0
#
#  dense_11 (Dense)            (None, 1)                 515
#
# =================================================================
# Total params: 549981 (2.10 MB)
# Trainable params: 549981 (2.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model3.compile(loss='binary_crossentropy',  optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), metrics=['accuracy'])
train_history = model3.fit(x= x_train, y=y_train,  validation_split=0.33, epochs= 100,  batch_size=50, verbose=2)
# Out:
# Epoch 1/100
# 76/76 - 2s - loss: 737.6738 - accuracy: 0.6261 - val_loss: 0.6659 - val_accuracy: 0.7371 - 2s/epoch - 26ms/step
# Epoch 2/100
# 76/76 - 1s - loss: 0.6459 - accuracy: 0.7236 - val_loss: 0.6137 - val_accuracy: 0.7366 - 1s/epoch - 19ms/step
# Epoch 3/100
# 76/76 - 1s - loss: 0.6039 - accuracy: 0.7300 - val_loss: 0.5888 - val_accuracy: 0.7371 - 1s/epoch - 14ms/step
# Epoch 4/100
# 76/76 - 1s - loss: 0.5963 - accuracy: 0.7281 - val_loss: 0.5785 - val_accuracy: 0.7371 - 839ms/epoch - 11ms/step
# Epoch 5/100
# 76/76 - 1s - loss: 0.5719 - accuracy: 0.7316 - val_loss: 0.5744 - val_accuracy: 0.7371 - 841ms/epoch - 11ms/step
# Epoch 6/100
# 76/76 - 1s - loss: 0.5852 - accuracy: 0.7284 - val_loss: 0.5738 - val_accuracy: 0.7360 - 906ms/epoch - 12ms/step
# Epoch 7/100
# 76/76 - 1s - loss: 0.5809 - accuracy: 0.7295 - val_loss: 0.5653 - val_accuracy: 0.7387 - 873ms/epoch - 11ms/step
# Epoch 8/100
# 76/76 - 1s - loss: 2.1204 - accuracy: 0.7239 - val_loss: 0.5721 - val_accuracy: 0.7371 - 891ms/epoch - 12ms/step
# Epoch 9/100
# 76/76 - 1s - loss: 0.5836 - accuracy: 0.7313 - val_loss: 0.5705 - val_accuracy: 0.7376 - 888ms/epoch - 12ms/step
# Epoch 10/100
# 76/76 - 1s - loss: 0.5727 - accuracy: 0.7334 - val_loss: 0.5695 - val_accuracy: 0.7398 - 803ms/epoch - 11ms/step
# Epoch 11/100
# 76/76 - 1s - loss: 0.5687 - accuracy: 0.7326 - val_loss: 0.5698 - val_accuracy: 0.7392 - 809ms/epoch - 11ms/step
# Epoch 12/100
# 76/76 - 1s - loss: 0.5712 - accuracy: 0.7326 - val_loss: 0.5674 - val_accuracy: 0.7398 - 870ms/epoch - 11ms/step
# Epoch 13/100
# 76/76 - 1s - loss: 0.5692 - accuracy: 0.7342 - val_loss: 0.5739 - val_accuracy: 0.7398 - 1s/epoch - 14ms/step
# Epoch 14/100
# 76/76 - 1s - loss: 0.5777 - accuracy: 0.7353 - val_loss: 0.5715 - val_accuracy: 0.7387 - 1s/epoch - 20ms/step
# Epoch 15/100
# 76/76 - 2s - loss: 0.5692 - accuracy: 0.7313 - val_loss: 0.5753 - val_accuracy: 0.7349 - 2s/epoch - 22ms/step
# Epoch 16/100
# 76/76 - 2s - loss: 0.5656 - accuracy: 0.7353 - val_loss: 0.5673 - val_accuracy: 0.7387 - 2s/epoch - 23ms/step
# Epoch 17/100
# 76/76 - 1s - loss: 0.5637 - accuracy: 0.7324 - val_loss: 0.5586 - val_accuracy: 0.7409 - 833ms/epoch - 11ms/step
# Epoch 18/100
# 76/76 - 1s - loss: 0.5607 - accuracy: 0.7345 - val_loss: 0.5680 - val_accuracy: 0.7398 - 846ms/epoch - 11ms/step
# Epoch 19/100
# 76/76 - 1s - loss: 0.5672 - accuracy: 0.7340 - val_loss: 0.5640 - val_accuracy: 0.7392 - 832ms/epoch - 11ms/step
# Epoch 20/100
# 76/76 - 1s - loss: 0.5653 - accuracy: 0.7326 - val_loss: 0.5734 - val_accuracy: 0.7387 - 887ms/epoch - 12ms/step
# Epoch 21/100
# 76/76 - 1s - loss: 0.5616 - accuracy: 0.7366 - val_loss: 0.5787 - val_accuracy: 0.7403 - 861ms/epoch - 11ms/step
# Epoch 22/100
# 76/76 - 1s - loss: 0.5735 - accuracy: 0.7321 - val_loss: 0.5773 - val_accuracy: 0.7403 - 913ms/epoch - 12ms/step
# Epoch 23/100
# 76/76 - 1s - loss: 0.5670 - accuracy: 0.7334 - val_loss: 0.5675 - val_accuracy: 0.7409 - 843ms/epoch - 11ms/step
# Epoch 24/100
# 76/76 - 1s - loss: 0.5696 - accuracy: 0.7324 - val_loss: 0.5717 - val_accuracy: 0.7392 - 849ms/epoch - 11ms/step
# Epoch 25/100
# 76/76 - 1s - loss: 0.5668 - accuracy: 0.7358 - val_loss: 0.5657 - val_accuracy: 0.7398 - 753ms/epoch - 10ms/step
# Epoch 26/100
# 76/76 - 1s - loss: 0.5705 - accuracy: 0.7332 - val_loss: 0.5707 - val_accuracy: 0.7382 - 855ms/epoch - 11ms/step
# Epoch 27/100
# 76/76 - 1s - loss: 0.5612 - accuracy: 0.7356 - val_loss: 0.5691 - val_accuracy: 0.7403 - 1s/epoch - 15ms/step
# Epoch 28/100
# 76/76 - 2s - loss: 0.5648 - accuracy: 0.7371 - val_loss: 0.5688 - val_accuracy: 0.7382 - 2s/epoch - 20ms/step
# Epoch 29/100
# 76/76 - 1s - loss: 0.5703 - accuracy: 0.7318 - val_loss: 0.5709 - val_accuracy: 0.7403 - 894ms/epoch - 12ms/step
# Epoch 30/100
# 76/76 - 1s - loss: 0.5698 - accuracy: 0.7358 - val_loss: 0.5769 - val_accuracy: 0.7392 - 869ms/epoch - 11ms/step
# Epoch 31/100
# 76/76 - 1s - loss: 0.5661 - accuracy: 0.7371 - val_loss: 0.5753 - val_accuracy: 0.7398 - 877ms/epoch - 12ms/step
# Epoch 32/100
# 76/76 - 1s - loss: 0.5678 - accuracy: 0.7361 - val_loss: 0.5694 - val_accuracy: 0.7398 - 830ms/epoch - 11ms/step
# Epoch 33/100
# 76/76 - 1s - loss: 0.5634 - accuracy: 0.7332 - val_loss: 0.5671 - val_accuracy: 0.7403 - 890ms/epoch - 12ms/step
# Epoch 34/100
# 76/76 - 1s - loss: 0.5607 - accuracy: 0.7382 - val_loss: 0.5757 - val_accuracy: 0.7382 - 896ms/epoch - 12ms/step
# Epoch 35/100
# 76/76 - 1s - loss: 0.5715 - accuracy: 0.7369 - val_loss: 0.5617 - val_accuracy: 0.7387 - 820ms/epoch - 11ms/step
# Epoch 36/100
# 76/76 - 1s - loss: 0.5614 - accuracy: 0.7358 - val_loss: 0.5720 - val_accuracy: 0.7382 - 779ms/epoch - 10ms/step
# Epoch 37/100
# 76/76 - 1s - loss: 0.5601 - accuracy: 0.7350 - val_loss: 0.5828 - val_accuracy: 0.7409 - 828ms/epoch - 11ms/step
# Epoch 38/100
# 76/76 - 1s - loss: 0.5664 - accuracy: 0.7361 - val_loss: 0.5725 - val_accuracy: 0.7414 - 792ms/epoch - 10ms/step
# Epoch 39/100
# 76/76 - 1s - loss: 0.5568 - accuracy: 0.7398 - val_loss: 0.5638 - val_accuracy: 0.7403 - 861ms/epoch - 11ms/step
# Epoch 40/100
# 76/76 - 1s - loss: 0.5599 - accuracy: 0.7369 - val_loss: 0.5675 - val_accuracy: 0.7403 - 1s/epoch - 14ms/step
# Epoch 41/100
# 76/76 - 1s - loss: 0.5719 - accuracy: 0.7329 - val_loss: 0.5692 - val_accuracy: 0.7409 - 1s/epoch - 17ms/step
# Epoch 42/100
# 76/76 - 1s - loss: 0.5656 - accuracy: 0.7364 - val_loss: 0.5673 - val_accuracy: 0.7403 - 1s/epoch - 13ms/step
# Epoch 43/100
# 76/76 - 1s - loss: 0.5618 - accuracy: 0.7387 - val_loss: 0.5710 - val_accuracy: 0.7376 - 1s/epoch - 13ms/step
# Epoch 44/100
# 76/76 - 2s - loss: 0.5699 - accuracy: 0.7326 - val_loss: 0.5750 - val_accuracy: 0.7403 - 2s/epoch - 24ms/step
# Epoch 45/100
# 76/76 - 2s - loss: 0.5653 - accuracy: 0.7379 - val_loss: 0.5762 - val_accuracy: 0.7414 - 2s/epoch - 21ms/step
# Epoch 46/100
# 76/76 - 2s - loss: 0.5611 - accuracy: 0.7369 - val_loss: 0.5843 - val_accuracy: 0.7403 - 2s/epoch - 22ms/step
# Epoch 47/100
# 76/76 - 2s - loss: 0.5644 - accuracy: 0.7348 - val_loss: 0.5762 - val_accuracy: 0.7414 - 2s/epoch - 20ms/step
# Epoch 48/100
# 76/76 - 2s - loss: 0.5679 - accuracy: 0.7350 - val_loss: 0.5716 - val_accuracy: 0.7398 - 2s/epoch - 24ms/step
# Epoch 49/100
# 76/76 - 3s - loss: 0.5648 - accuracy: 0.7334 - val_loss: 0.5703 - val_accuracy: 0.7382 - 3s/epoch - 34ms/step
# Epoch 50/100
# 76/76 - 2s - loss: 0.5742 - accuracy: 0.7348 - val_loss: 0.5688 - val_accuracy: 0.7398 - 2s/epoch - 27ms/step
# Epoch 51/100
# 76/76 - 2s - loss: 0.5668 - accuracy: 0.7342 - val_loss: 0.5652 - val_accuracy: 0.7398 - 2s/epoch - 23ms/step
# Epoch 52/100
# 76/76 - 1s - loss: 0.5597 - accuracy: 0.7353 - val_loss: 0.5819 - val_accuracy: 0.7414 - 1s/epoch - 20ms/step
# Epoch 53/100
# 76/76 - 1s - loss: 0.5551 - accuracy: 0.7390 - val_loss: 0.5763 - val_accuracy: 0.7387 - 1s/epoch - 18ms/step
# Epoch 54/100
# 76/76 - 1s - loss: 0.5595 - accuracy: 0.7369 - val_loss: 0.5668 - val_accuracy: 0.7387 - 873ms/epoch - 11ms/step
# Epoch 55/100
# 76/76 - 1s - loss: 0.5650 - accuracy: 0.7353 - val_loss: 0.5673 - val_accuracy: 0.7414 - 793ms/epoch - 10ms/step
# Epoch 56/100
# 76/76 - 1s - loss: 0.5623 - accuracy: 0.7329 - val_loss: 0.5723 - val_accuracy: 0.7414 - 854ms/epoch - 11ms/step
# Epoch 57/100
# 76/76 - 1s - loss: 0.5614 - accuracy: 0.7353 - val_loss: 0.5802 - val_accuracy: 0.7403 - 804ms/epoch - 11ms/step
# Epoch 58/100
# 76/76 - 1s - loss: 0.5577 - accuracy: 0.7395 - val_loss: 0.5904 - val_accuracy: 0.7392 - 1s/epoch - 17ms/step
# Epoch 59/100
# 76/76 - 1s - loss: 0.5703 - accuracy: 0.7369 - val_loss: 0.5764 - val_accuracy: 0.7403 - 1s/epoch - 17ms/step
# Epoch 60/100
# 76/76 - 1s - loss: 0.5717 - accuracy: 0.7340 - val_loss: 0.5733 - val_accuracy: 0.7398 - 859ms/epoch - 11ms/step
# Epoch 61/100
# 76/76 - 1s - loss: 0.5626 - accuracy: 0.7361 - val_loss: 0.5738 - val_accuracy: 0.7387 - 825ms/epoch - 11ms/step
# Epoch 62/100
# 76/76 - 1s - loss: 0.5641 - accuracy: 0.7345 - val_loss: 0.5934 - val_accuracy: 0.7409 - 900ms/epoch - 12ms/step
# Epoch 63/100
# 76/76 - 1s - loss: 0.5727 - accuracy: 0.7337 - val_loss: 0.5841 - val_accuracy: 0.7398 - 873ms/epoch - 11ms/step
# Epoch 64/100
# 76/76 - 1s - loss: 0.5691 - accuracy: 0.7361 - val_loss: 0.5853 - val_accuracy: 0.7398 - 862ms/epoch - 11ms/step
# Epoch 65/100
# 76/76 - 1s - loss: 0.5812 - accuracy: 0.7340 - val_loss: 0.5816 - val_accuracy: 0.7398 - 872ms/epoch - 11ms/step
# Epoch 66/100
# 76/76 - 1s - loss: 0.5654 - accuracy: 0.7348 - val_loss: 0.6155 - val_accuracy: 0.7392 - 860ms/epoch - 11ms/step
# Epoch 67/100
# 76/76 - 1s - loss: 0.5747 - accuracy: 0.7374 - val_loss: 0.5875 - val_accuracy: 0.7403 - 885ms/epoch - 12ms/step
# Epoch 68/100
# 76/76 - 1s - loss: 0.5759 - accuracy: 0.7364 - val_loss: 0.5752 - val_accuracy: 0.7398 - 866ms/epoch - 11ms/step
# Epoch 69/100
# 76/76 - 1s - loss: 0.5669 - accuracy: 0.7374 - val_loss: 0.5766 - val_accuracy: 0.7387 - 875ms/epoch - 12ms/step
# Epoch 70/100
# 76/76 - 1s - loss: 0.5724 - accuracy: 0.7364 - val_loss: 0.5743 - val_accuracy: 0.7387 - 845ms/epoch - 11ms/step
# Epoch 71/100
# 76/76 - 1s - loss: 0.5725 - accuracy: 0.7324 - val_loss: 0.5901 - val_accuracy: 0.7398 - 1s/epoch - 17ms/step
# Epoch 72/100
# 76/76 - 1s - loss: 0.5696 - accuracy: 0.7353 - val_loss: 0.5796 - val_accuracy: 0.7403 - 1s/epoch - 19ms/step
# Epoch 73/100
# 76/76 - 1s - loss: 0.5709 - accuracy: 0.7340 - val_loss: 0.5843 - val_accuracy: 0.7398 - 850ms/epoch - 11ms/step
# Epoch 74/100
# 76/76 - 1s - loss: 0.5679 - accuracy: 0.7348 - val_loss: 0.5938 - val_accuracy: 0.7360 - 821ms/epoch - 11ms/step
# Epoch 75/100
# 76/76 - 1s - loss: 0.5689 - accuracy: 0.7345 - val_loss: 0.5820 - val_accuracy: 0.7409 - 817ms/epoch - 11ms/step
# Epoch 76/100
# 76/76 - 1s - loss: 0.5614 - accuracy: 0.7364 - val_loss: 0.5819 - val_accuracy: 0.7387 - 835ms/epoch - 11ms/step
# Epoch 77/100
# 76/76 - 1s - loss: 0.5644 - accuracy: 0.7369 - val_loss: 0.6132 - val_accuracy: 0.7409 - 833ms/epoch - 11ms/step
# Epoch 78/100
# 76/76 - 1s - loss: 0.5784 - accuracy: 0.7353 - val_loss: 0.6377 - val_accuracy: 0.7403 - 844ms/epoch - 11ms/step
# Epoch 79/100
# 76/76 - 1s - loss: 0.5804 - accuracy: 0.7348 - val_loss: 0.6103 - val_accuracy: 0.7403 - 890ms/epoch - 12ms/step
# Epoch 80/100
# 76/76 - 1s - loss: 0.5756 - accuracy: 0.7337 - val_loss: 0.6451 - val_accuracy: 0.7398 - 899ms/epoch - 12ms/step
# Epoch 81/100
# 76/76 - 1s - loss: 0.5868 - accuracy: 0.7361 - val_loss: 0.5828 - val_accuracy: 0.7398 - 817ms/epoch - 11ms/step
# Epoch 82/100
# 76/76 - 1s - loss: 0.5868 - accuracy: 0.7334 - val_loss: 0.5777 - val_accuracy: 0.7392 - 914ms/epoch - 12ms/step
# Epoch 83/100
# 76/76 - 1s - loss: 0.5777 - accuracy: 0.7348 - val_loss: 0.5805 - val_accuracy: 0.7398 - 862ms/epoch - 11ms/step
# Epoch 84/100
# 76/76 - 1s - loss: 0.5798 - accuracy: 0.7334 - val_loss: 0.5774 - val_accuracy: 0.7392 - 1s/epoch - 17ms/step
# Epoch 85/100
# 76/76 - 1s - loss: 0.5840 - accuracy: 0.7334 - val_loss: 0.5861 - val_accuracy: 0.7382 - 1s/epoch - 19ms/step
# Epoch 86/100
# 76/76 - 1s - loss: 0.5757 - accuracy: 0.7342 - val_loss: 0.5892 - val_accuracy: 0.7376 - 814ms/epoch - 11ms/step
# Epoch 87/100
# 76/76 - 1s - loss: 0.5710 - accuracy: 0.7334 - val_loss: 0.5758 - val_accuracy: 0.7382 - 838ms/epoch - 11ms/step
# Epoch 88/100
# 76/76 - 1s - loss: 0.5744 - accuracy: 0.7334 - val_loss: 0.5865 - val_accuracy: 0.7403 - 843ms/epoch - 11ms/step
# Epoch 89/100
# 76/76 - 1s - loss: 0.5685 - accuracy: 0.7358 - val_loss: 0.6010 - val_accuracy: 0.7403 - 859ms/epoch - 11ms/step
# Epoch 90/100
# 76/76 - 1s - loss: 0.5675 - accuracy: 0.7361 - val_loss: 0.5863 - val_accuracy: 0.7403 - 874ms/epoch - 11ms/step
# Epoch 91/100
# 76/76 - 1s - loss: 0.5701 - accuracy: 0.7329 - val_loss: 0.5886 - val_accuracy: 0.7376 - 827ms/epoch - 11ms/step
# Epoch 92/100
# 76/76 - 2s - loss: 0.5654 - accuracy: 0.7369 - val_loss: 0.6009 - val_accuracy: 0.7387 - 2s/epoch - 21ms/step
# Epoch 93/100
# 76/76 - 1s - loss: 0.5716 - accuracy: 0.7353 - val_loss: 0.6737 - val_accuracy: 0.7409 - 870ms/epoch - 11ms/step
# Epoch 94/100
# 76/76 - 1s - loss: 0.6546 - accuracy: 0.7348 - val_loss: 0.5889 - val_accuracy: 0.7403 - 820ms/epoch - 11ms/step
# Epoch 95/100
# 76/76 - 1s - loss: 0.5735 - accuracy: 0.7350 - val_loss: 0.5897 - val_accuracy: 0.7409 - 869ms/epoch - 11ms/step
# Epoch 96/100
# 76/76 - 1s - loss: 0.5762 - accuracy: 0.7356 - val_loss: 0.6048 - val_accuracy: 0.7371 - 1s/epoch - 14ms/step
# Epoch 97/100
# 76/76 - 1s - loss: 0.5728 - accuracy: 0.7311 - val_loss: 0.6091 - val_accuracy: 0.7398 - 1s/epoch - 19ms/step
# Epoch 98/100
# 76/76 - 1s - loss: 0.5701 - accuracy: 0.7332 - val_loss: 0.6107 - val_accuracy: 0.7392 - 972ms/epoch - 13ms/step
# Epoch 99/100
# 76/76 - 1s - loss: 0.5687 - accuracy: 0.7356 - val_loss: 0.5893 - val_accuracy: 0.7387 - 839ms/epoch - 11ms/step
# Epoch 100/100
# 76/76 - 1s - loss: 0.6004 - accuracy: 0.7321 - val_loss: 0.5919 - val_accuracy: 0.7392 - 810ms/epoch - 11ms/step

# %%
show_train_history(train_history,'accuracy','val_accuracy')
show_train_history(train_history,'loss','val_loss')

# %%
scores = model3.evaluate(x_test, y_test)
print('\n')
print('accuracy=',scores[1])
# Out:
# 45/45 [==============================] - 0s 3ms/step - loss: 0.5593 - accuracy: 0.7459
#
#
# accuracy= 0.7459191083908081

# %%
y_pred3 = model3.predict(x_test)
accuracy3 = accuracy_score(y_test, np.argmax(y_pred3, axis=1))
f13 = f1_score(y_test, np.argmax(y_pred3, axis=1))
roc_auc3 = roc_auc_score(tf.keras.utils.to_categorical(y_test), y_pred3)
# Out:
# 45/45 [==============================] - 0s 3ms/step

# %%
y_pred3 = (y_pred3>0.5)

# %%
cm = confusion_matrix(y_pred3,y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('True')
plt.ylabel('Predicted')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_test,y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.85      1045
#            1       0.88      0.02      0.04       364
#
#     accuracy                           0.75      1409
#    macro avg       0.81      0.51      0.45      1409
# weighted avg       0.78      0.75      0.64      1409

# %% [markdown]
# *Implementing Monte Carlo Dropout...*

# %%
def monte_carlo_inference(model, x, num_samples):
  y_preds = np.zeros((num_samples, x.shape[0], 10))
  for i in range(num_samples):
    y_preds[i] = tf.nn.softmax(model(x, training=True)).numpy()
  return y_preds

# %%
x_test = np.array(x_test)

# %%
# Perform Monte Carlo Dropout inference on test data
y_preds_mc = monte_carlo_inference(model3, x_test, 10)

# %%
y_preds_mc = (y_preds_mc>0.5)

# %%
mean_prediction = np.mean(y_preds_mc, axis=0)
uncertainty = np.std(y_preds_mc, axis=0)

# %%
# Evaluate accuracy
accuracy = np.mean(np.argmax(mean_prediction, axis=1) == y_test)
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 74.17%

# %%
conf_matrix = confusion_matrix(y_test, np.argmax(mean_prediction, axis=1))
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('True')
plt.ylabel('Predicted')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ###Comparison and Visualization

# %%
fpr1, tpr1, _ = roc_curve(y_test, y_pred1)
roc_auc1 = auc(fpr1, tpr1)
fpr2, tpr2, _ = roc_curve(y_test, y_pred2)
roc_auc2 = auc(fpr2, tpr2)
fpr3, tpr3, _ = roc_curve(y_test, y_pred3)
roc_auc3 = auc(fpr3, tpr3)
fpr4, tpr4, _ = roc_curve(y_test, np.argmax(mean_prediction, axis=1))
roc_auc4 = auc(fpr4, tpr4)
# Plot ROC curves
plt.plot(fpr1, tpr1, label='Simple DNN' % roc_auc1)
plt.plot(fpr2, tpr2, label='DNN with Dropout (AUC = %0.2f)' % roc_auc2)
plt.plot(fpr3, tpr3, label='Layer-Wise Dropout (AUC = %0.2f)' % roc_auc3)
plt.plot(fpr4, tpr4, label='Monte Carlo Dropout (AUC = %0.2f)' % roc_auc4)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
accuracies = {'Baseline': accuracy1,'Dropout': accuracy2,'Layer-wise Dropout': accuracy3,'Monte Carlo Dropout': accuracy}
# Plot accuracies
plt.figure(figsize=(10, 6))
bars = plt.bar(accuracies.keys(), accuracies.values(), color=['blue', 'orange', 'green', 'red'])
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison of Different Models')
plt.ylim(0, 1)
plt.xticks(rotation=45)
for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')
plt.show()
