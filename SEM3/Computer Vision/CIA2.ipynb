# %% [markdown]
# <a href="https://colab.research.google.com/github/Shiladitya56/Machine-Learning/blob/main/SEM3/Computer%20Vision/CIA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Shiladitya **2348556** 🥷

# %% [markdown]
# #We use the following image for our test purposes

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('dead.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=728x507>

# %% [markdown]
# #Program 1

# %% [markdown]
# ##Translation

# %%
h, w = image.shape[:2]
tx = 100
ty = 50
trans = np.float32([[1, 0, tx], [0, 1, ty]])
trans_im = cv2.warpAffine(image, trans, (w, h))
cv2_imshow(trans_im)
# Out:
# <PIL.Image.Image image mode=RGB size=728x507>

# %% [markdown]
# ##Scaling

# %%
sx = 0.5
sy = 0.5
scale = np.float32([[sx, 0, 0], [0, sy, 0]])
scaled_im = cv2.warpAffine(image, scale, (w,h))
cv2_imshow(scaled_im)
# Out:
# <PIL.Image.Image image mode=RGB size=728x507>

# %% [markdown]
# ##Rotation

# %%
angle = 45
rotation = cv2.getRotationMatrix2D((w / 2, h / 2), angle, 1)
rotated_im = cv2.warpAffine(image, rotation, (w, h))
cv2_imshow(rotated_im)
# Out:
# <PIL.Image.Image image mode=RGB size=728x507>

# %% [markdown]
# #Program 2

# %% [markdown]
# ##Average filter

# %%
ks = (23, 23)
avg_im = cv2.blur(image, ks)
cv2_imshow(avg_im)
# Out:
# <PIL.Image.Image image mode=RGB size=728x507>

# %% [markdown]
# ##Laplacian filter

# %%
lap = np.array([[0, 1, 0],
                [1, -4, 1],
                [0, 1, 0]])
lap_im = cv2.filter2D(image, -1, lap)
cv2_imshow(lap_im)
# Out:
# <PIL.Image.Image image mode=RGB size=728x507>
