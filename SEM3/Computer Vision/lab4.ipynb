# %% [markdown]
# <a href="https://colab.research.google.com/github/Shiladitya56/Machine-Learning/blob/main/SEM3/Computer%20Vision/lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Shiladitya 2348556 ⛄

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
def linear_spatial_filter(img, krnl):
  imh, imw = img.shape
  krh, krw = krnl.shape
  pah = krh // 2
  paw = krw // 2
  padim = np.pad(img, ((pah, pah), (paw, paw)), mode='constant')
  outim = np.zeros_like(img)
  for i in range(imh):
    for j in range(imw):
      outim[i, j] = np.sum(padim[i:i+krh, j:j+krw] * krnl)
  return outim.astype(np.uint8)

# %%
image = cv2.resize(cv2.imread('dead2.jpg', cv2.IMREAD_GRAYSCALE), (400,260))
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=400x260>

# %%
# Define filter kernel (e.g., gaussian kernel)
kernel = 1/16*np.array([[1, 2, 1],
                        [2, 4, 2],
                        [1, 2, 1]])

filtered_image = linear_spatial_filter(image, kernel)
cv2_imshow(filtered_image)
# Out:
# <PIL.Image.Image image mode=L size=400x260>

# %%
kernel = np.array([[-1,-1,-1],
                   [-1, 9,-1],
                   [-1,-1,-1]])
filtered_image = linear_spatial_filter(image, kernel)
cv2_imshow(filtered_image)
# Out:
# <PIL.Image.Image image mode=L size=400x260>

# %%
kernel = np.ones((4,4))/16
filtered_image = linear_spatial_filter(image, kernel)
cv2_imshow(filtered_image)
# Out:
# <PIL.Image.Image image mode=L size=400x260>

# %%
cv2.GaussianBlur(image, (5, 5), 0)
# Out:
# array([[253, 253, 253, ..., 253, 253, 253],
#        [253, 253, 253, ..., 253, 253, 253],
#        [253, 253, 253, ..., 253, 253, 253],
#        ...,
#        [253, 253, 253, ...,  77,  86,  90],
#        [253, 253, 253, ...,  78,  84,  86],
#        [253, 253, 253, ...,  79,  83,  85]], dtype=uint8)

# %%
cv2.blur(image, (5, 5))
# Out:
# array([[253, 253, 253, ..., 253, 253, 253],
#        [253, 253, 253, ..., 253, 253, 253],
#        [253, 253, 253, ..., 253, 253, 253],
#        ...,
#        [253, 253, 253, ...,  77,  83,  86],
#        [253, 253, 253, ...,  78,  81,  86],
#        [253, 253, 253, ...,  78,  81,  85]], dtype=uint8)

# %%
cv2_imshow(cv2.Laplacian(image, cv2.CV_64F))
# Out:
# <PIL.Image.Image image mode=L size=400x260>
