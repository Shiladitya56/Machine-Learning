# %% [markdown]
# <a href="https://colab.research.google.com/github/Shiladitya56/Machine-Learning/blob/main/SEM3/Natural%20Language%20Processing/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Shiladitya 2348556 ⛺

# %% [markdown]
# <a href="https://colab.research.google.com/github/swastikbanerjee/NLP_Lab/blob/main/nlpLab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sample Paragraph

# %%
import nltk
import re
import matplotlib.pyplot as plt
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer
from nltk.util import ngrams
text = "The horology of mechanical watches represents a captivating blend of artistry, precision engineering, and timeless tradition. At its core, mechanical horology encompasses the intricate mechanisms that power these watches, often comprised of hundreds of precisely crafted components working in harmony. The first of its kind came to form in the 1940. From the mesmerizing dance of gears and springs in a manual-wind movement to the seamless oscillation of a balance wheel in an automatic movement, each element plays a crucial role in measuring time with remarkable accuracy. Since 1940 beyond mere functionality, mechanical watches also serve as expressions of craftsmanship and heritage, with skilled artisans meticulously assembling and finishing each piece by hand. In the 2000, the allure of mechanical horology lies not only in its ability to keep time but also in its ability to evoke a sense of nostalgia and appreciation for the artistry of a bygone era."

# %% [markdown]
# a. Count the number of unique tokens in the text.

# %%
nltk.download('punkt')
tokens = word_tokenize(text)
unique_tokens_count = len(set(tokens))
print("Number of unique tokens:", unique_tokens_count)
# Out:
# Number of unique tokens: 99
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# b. Count the number of punctuation characters and remove punctuations.

# %%
punctuations = re.findall(r'[^\w\s]', text)
punctuation_count = len(punctuations)
text_without_punctuation = re.sub(r'[^\w\s]', '', text)
print("Number of punctuation characters:", punctuation_count)
print("Text without punctuation:", text_without_punctuation)
# Out:
# Number of punctuation characters: 15
# ...

# %% [markdown]
# c. Plot the distribution of stopwords used in the text using barplot.

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
stopwords_in_text = [word for word in tokens if word.lower() in stop_words]
stopword_distribution = Counter(stopwords_in_text)
plt.bar(stopword_distribution.keys(), stopword_distribution.values(), color='orchid')
plt.xlabel('Stopwords')
plt.ylabel('Frequency')
plt.title('Distribution of Stopwords')
plt.xticks(rotation=45)
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# d. Remove the stopwords from the text.

# %%
filtered_text = [word for word in tokens if word.lower() not in stop_words]
print(filtered_text)
# Out:
# ['horology', 'mechanical', 'watches', 'represents', 'captivating', 'blend', 'artistry', ',', 'precision', 'engineering', ',', 'timeless', 'tradition', '.', 'core', ',', 'mechanical', 'horology', 'encompasses', 'intricate', 'mechanisms', 'power', 'watches', ',', 'often', 'comprised', 'hundreds', 'precisely', 'crafted', 'components', 'working', 'harmony', '.', 'first', 'kind', 'came', 'form', '1940', '.', 'mesmerizing', 'dance', 'gears', 'springs', 'manual-wind', 'movement', 'seamless', 'oscillation', 'balance', 'wheel', 'automatic', 'movement', ',', 'element', 'plays', 'crucial', 'role', 'measuring', 'time', 'remarkable', 'accuracy', '.', 'Since', '1940', 'beyond', 'mere', 'functionality', ',', 'mechanical', 'watches', 'also', 'serve', 'expressions', 'craftsmanship', 'heritage', ',', 'skilled', 'artisans', 'meticulously', 'assembling', 'finishing', 'piece', 'hand', '.', '2000', ',', 'allure', 'mechanical', 'horology', 'lies', 'ability', 'keep', 'time', 'also', 'ability', 'evoke', 'sen
# ...

# %% [markdown]
# e. Plot the distribution of each POS Tag using a barplot.

# %%
nltk.download('averaged_perceptron_tagger')
pos_tags = pos_tag(tokens)
pos_distribution = Counter(tag for word, tag in pos_tags)
plt.bar(pos_distribution.keys(), pos_distribution.values(), color='orchid')
plt.xlabel('POS Tags')
plt.ylabel('Frequency')
plt.title('Distribution of POS Tags')
plt.xticks(rotation=45)
plt.show()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# f. Determine the number of unique lemma available in the text.

# %%
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
lemmas = [lemmatizer.lemmatize(word) for word in tokens]
unique_lemmas_count = len(set(lemmas))
print("Number of unique lemmas:", unique_lemmas_count)
# Out:
# Number of unique lemmas: 98
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# g. Plot the frequency distribution of words in the text. Display only the top 10 (most occurring) tokens in the chart.

# %%
word_frequency = Counter(filtered_text)
top_10_tokens = word_frequency.most_common(10)
plt.bar(*zip(*top_10_tokens), color='orchid')
plt.xlabel('Tokens')
plt.ylabel('Frequency')
plt.title('Top 10 Tokens')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# h. Find the number of unique bigrams, trigrams and quadgrams (n=4) in the corpus

# %%
bigrams = ngrams(filtered_text, 2)
trigrams = ngrams(filtered_text, 3)
quadgrams = ngrams(filtered_text, 4)
unique_bigrams_count = len(set(bigrams))
unique_trigrams_count = len(set(trigrams))
unique_quadgrams_count = len(set(quadgrams))
print("Number of unique bigrams:", unique_bigrams_count)
print("Number of unique trigrams:", unique_trigrams_count)
print("Number of unique quadgrams:", unique_quadgrams_count)
# Out:
# Number of unique bigrams: 98
# Number of unique trigrams: 100
# Number of unique quadgrams: 99

# %% [markdown]
# i. Find all dates and convert them to the DD-MM-YYYY format.

# %%
from datetime import datetime
dates = re.findall(r'\b(?:0?[1-9]|[12][0-9]|3[01])-(?:January|February|March|April|May|June|July|August|September|October|November|December)-\d{4}\b', text)
converted_dates = []
for date in dates:
    dt_obj = datetime.strptime(date, '%d-%B-%Y')
    converted_dates.append(dt_obj.strftime('%d-%m-%Y'))
print("Dates found:", converted_dates)
# Out:
# Dates found: []

# %% [markdown]
# j. Plot a distribution of the different values of year occurring in the text.

# %%
years = re.findall(r'\b\d{4}\b', text)
year_distribution = Counter(years)
plt.bar(year_distribution.keys(), year_distribution.values(), color='orchid')
plt.xlabel('Years')
plt.ylabel('Frequency')
plt.title('Distribution of Years')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# k. Determine whether the text contains any phone numbers in it.

# %%
phone_numbers = re.findall(r'\b(?:\+?(\d{1,2}))?[-. ]?(\d{3})[-. ]?(\d{3})[-. ]?(\d{4})\b', text)
valid_phone_numbers = []
for number in phone_numbers:
    formatted_number = '-'.join(number)
    valid_phone_numbers.append(formatted_number)
if valid_phone_numbers:
    print("Valid phone numbers found:", valid_phone_numbers)
else:
    print("No valid phone numbers found.")
# Out:
# No valid phone numbers found.

# %% [markdown]
# a. Counting the number of unique tokens:
#    - Insights: This operation helps in understanding the vocabulary richness and diversity within the text. It gives an idea of the breadth of topics covered or the range of expressions used.
#    - Possible applications: Useful in text analysis tasks such as text summarization, keyword extraction, and topic modeling. Also helps in identifying repetitive or uncommon terms.
#
# b. Counting the number of punctuation characters and removing punctuations:
#    - Insights: Punctuation marks can provide insights into the writing style and emphasis within the text. Removing them helps focus on the actual content.
#    - Possible applications: Preprocessing step in natural language processing tasks such as sentiment analysis, text classification, and machine translation.
#
# c. Plotting the distribution of stopwords used in the text:
#    - Insights: Stopwords are common words that often do not carry much meaning individually. Their distribution can indicate the writing style or genre of the text.
#    - Possible applications: Understanding the level of formality in the text, identifying common phrases or expressions, and improving search engine optimization by excluding stopwords from indexing.
#
# d. Removing stopwords from the text:
#    - Insights: Stopwords removal is crucial for many text analysis tasks as it eliminates noise and focuses on meaningful content.
#    - Possible applications: Improving the accuracy of text classification, topic modeling, and sentiment analysis by removing irrelevant words.
#
# e. Plotting the distribution of each POS Tag:
#    - Insights: Part-of-speech (POS) tagging provides insights into the grammatical structure of the text, revealing patterns of word usage and syntactic relationships.
#    - Possible applications: Enhancing syntactic parsing, named entity recognition, and information extraction tasks. Also useful in stylistic analysis and text generation.
#
# f. Determining the number of unique lemmas available in the text:
#    - Insights: Lemmatization reduces words to their base or dictionary form, which helps in standardizing vocabulary and reducing word variation.
#    - Possible applications: Improving the effectiveness of information retrieval, text similarity calculation, and topic modeling by grouping together different inflected forms of the same word.
#
# g. Plotting the frequency distribution of words in the text:
#    - Insights: Word frequency distribution reveals the prominence of specific terms in the text, highlighting key themes or topics.
#    - Possible applications: Identifying important keywords, detecting trends, and understanding the focus of the text. Useful in content analysis, text summarization, and keyword extraction.
#
# h. Finding the number of unique bigrams, trigrams, and quadgrams:
#    - Insights: N-grams capture collocations or sequences of words that often occur together, providing insights into language usage patterns.
#    - Possible applications: Enhancing language modeling, predictive text input, and text generation tasks. Also useful in identifying idiomatic expressions and common phrases.
#
# i. Finding and converting dates to DD-MM-YYYY format:
#    - Insights: Dates provide temporal context to the text, enabling analysis of events and timelines mentioned.
#    - Possible applications: Extracting temporal information for event detection, chronological ordering of documents, and timeline visualization.
#
# j. Plotting a distribution of the different values of years occurring in the text:
#    - Insights: Year distribution helps in understanding the temporal scope of the text and identifying periods of focus.
#    - Possible applications: Analyzing historical trends, identifying temporal patterns, and contextualizing text within specific timeframes.
#
# k. Determining whether the text contains any phone numbers:
#    - Insights: Phone numbers can indicate points of contact or reference within the text.
#    - Possible applications: Extracting contact information for further communication, building contact directories, and improving information retrieval for phone-based services.
#
# Overall, these operations provide valuable insights into the text data and enable a wide range of applications in natural language processing, text analysis, and information retrieval.
